# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# A fun fact: **bananas are naturally radioactive**—they contain a tiny amount of the isotope **potassium-40**, which all humans and plants have in small amounts.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A sealed box contains 12 identical-looking coins, but one is fake. The fake coin is either heavier or lighter than the genuine coins, but you do not know which. You have a balance scale and may use it exactly three times. How can you determine which coin is fake and whether it is heavier or lighter?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A sealed box contains 12 identical-looking coins, but one is fake. The fake coin is either heavier or lighter than the genuine coins, but you do not know which. You have a balance scale and may use it exactly three times. How can you determine which coin is fake and whether it is heavier or lighter?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Here is a standard 3-weighing strategy for the **12-coin problem**. Label the coins **1 to 12**.
#
# We’ll use the balance scale to narrow down the possibilities systematically.
#
# ---
#
# ## Weighing 1
# Weigh:
#
# **1, 2, 3, 4**  vs **5, 6, 7, 8**
#
# ### Case A: They balance
# Then coins **1–8 are genuine**, and the fake coin is among **9, 10, 11, 12**.
#
# Now weigh:
#
# **9, 10, 11** vs **1, 2, 3**
# (since 1,2,3 are known genuine)
#
# - If they balance, then **12** is fake.
#   - Weigh **12** vs **1**
#     - heavier → 12 is heavy
#     - lighter → 12 is light
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weigh **9** vs **10**
#     - if one is heavier, that one is fake and heavy
#     - if they balance, then **11** is fake and heavy
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weigh **9** vs **10**
#     - if one is lighter, that one is fake and light
#     - if they balance, then **11** is fake and light
#
# ---
#
# ## Case B: Left side is heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and **heavy**, or
# - one of **5, 6, 7, 8** and **light**
#
# And coins **9–12** are genuine.
#
# Now weigh:
#
# **1, 2, 5** vs **3, 6, 9**
#
# Here 9 is genuine.
#
# ### Subcase B1: Balance
# Then the fake is either:
# - **4 heavy**, or
# - **7 light**, or
# - **8 light**
#
# Weigh **7** vs **8**
# - if one is lighter, that one is fake and light
# - if they balance, then **4** is fake and heavy
#
# ### Subcase B2: Left side is heavier
# Then the fake is either:
# - **1 heavy**
# - **2 heavy**
# - **6 light**
#
# Weigh **1** vs **2**
# - if one is heavier, that one is fake and heavy
# - if they balance, then **6** is fake and light
#
# ### Subcase B3: Right side is heavier
# Then the fake is either:
# - **3 heavy**
# - **5 light**
#
# Weigh **3** vs **9**
# - if 3 is heavier, then **3** is fake and heavy
# - otherwise, **5** is fake and light
#
# ---
#
# ## Case C: Right side is heavier
# This is symmetric to Case B.
#
# Then the fake is either:
#
# - one of **1, 2, 3, 4** and **light**, or
# - one of **5, 6, 7, 8** and **heavy**
#
# Proceed with the same second weighing:
#
# **1, 2, 5** vs **3, 6, 9**
#
# The interpretation is the mirror image of Case B:
#
# - If it balances:
#   - fake is **4 light**, or **7 heavy**, or **8 heavy**
#   - weigh **7** vs **8**
#
# - If left side is heavier:
#   - fake is **3 light**, or **5 heavy**
#   - weigh **3** vs **9**
#
# - If right side is heavier:
#   - fake is **1 light**, **2 light**, or **6 heavy**
#   - weigh **1** vs **2**
#
# ---
#
# ## Summary
# With these three weighings, you can always identify:
#
# 1. **which coin is fake**
# 2. **whether it is heavier or lighter**
#
# ---
#
# If you want, I can also give you:
# - a **compact decision-tree table**, or
# - a **more elegant “balanced ternary” style solution**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here is a standard 3-weighing strategy for the **12-coin problem**. Label the coins **1 to 12**.
#
# We’ll use the balance scale to narrow down the possibilities systematically.
#
# ---
#
# ## Weighing 1
# Weigh:
#
# **1, 2, 3, 4**  vs **5, 6, 7, 8**
#
# ### Case A: They balance
# Then coins **1–8 are genuine**, and the fake coin is among **9, 10, 11, 12**.
#
# Now weigh:
#
# **9, 10, 11** vs **1, 2, 3**
# (since 1,2,3 are known genuine)
#
# - If they balance, then **12** is fake.
#   - Weigh **12** vs **1**
#     - heavier → 12 is heavy
#     - lighter → 12 is light
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weigh **9** vs **10**
#     - if one is heavier, that one is fake and heavy
#     - if they balance, then **11** is fake and heavy
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weigh **9** vs **10**
#     - if one is lighter, that one is fake and light
#     - if they balance, then **11** is fake and light
#
# ---
#
# ## Case B: Left side is heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and **heavy**, or
# - one of **5, 6, 7, 8** and **light**
#
# And coins **9–12** are genuine.
#
# Now weigh:
#
# **1, 2, 5** vs **3, 6, 9**
#
# Here 9 is genuine.
#
# ### Subcase B1: Balance
# Then the fake is either:
# - **4 heavy**, or
# - **7 light**, or
# - **8 light**
#
# Weigh **7** vs **8**
# - if one is lighter, that one is fake and light
# - if they balance, then **4** is fake and heavy
#
# ### Subcase B2: Left side is heavier
# Then the fake is either:
# - **1 heavy**
# - **2 heavy**
# - **6 light**
#
# Weigh **1** vs **2**
# - if one is heavier, that one is fake and heavy
# - if they balance, then **6** is fake and light
#
# ### Subcase B3: Right side is heavier
# Then the fake is either:
# - **3 heavy**
# - **5 light**
#
# Weigh **3** vs **9**
# - if 3 is heavier, then **3** is fake and heavy
# - otherwise, **5** is fake and light
#
# ---
#
# ## Case C: Right side is heavier
# This is symmetric to Case B.
#
# Then the fake is either:
#
# - one of **1, 2, 3, 4** and **light**, or
# - one of **5, 6, 7, 8** and **heavy**
#
# Proceed with the same second weighing:
#
# **1, 2, 5** vs **3, 6, 9**
#
# The interpretation is the mirror image of Case B:
#
# - If it balances:
#   - fake is **4 light**, or **7 heavy**, or **8 heavy**
#   - weigh **7** vs **8**
#
# - If left side is heavier:
#   - fake is **3 light**, or **5 heavy**
#   - weigh **3** vs **9**
#
# - If right side is heavier:
#   - fake is **1 light**, **2 light**, or **6 heavy**
#   - weigh **1** vs **2**
#
# ---
#
# ## Summary
# With these three weighings, you can always identify:
#
# 1. **which coin is fake**
# 2. **whether it is heavier or lighter**
#
# ---
#
# If you want, I can also give you:
# - a **compact decision-tree table**, or
# - a **more elegant “balanced ternary” style solution**.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A sealed box contains 12 identical-looking coins, but one is fake. The fake coin is either heavier or lighter than the genuine coins, but you do not know which. You have a balance scale and may use it exactly three times. How can you determine which coin is fake and whether it is heavier or lighter?
#
# And here is a possible answer that might be correct or incorrect:
# Here is a standard 3-weighing strategy for the **12-coin problem**. Label the coins **1 to 12**.
#
# We’ll use the balance scale to narrow down the possibilities systematically.
#
# ---
#
# ## Weighing 1
# Weigh:
#
# **1, 2, 3, 4**  vs **5, 6, 7, 8**
#
# ### Case A: They balance
# Then coins **1–8 are genuine**, and the fake coin is among **9, 10, 11, 12**.
#
# Now weigh:
#
# **9, 10, 11** vs **1, 2, 3**
# (since 1,2,3 are known genuine)
#
# - If they balance, then **12** is fake.
#   - Weigh **12** vs **1**
#     - heavier → 12 is heavy
#     - lighter → 12 is light
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weigh **9** vs **10**
#     - if one is heavier, that one is fake and heavy
#     - if they balance, then **11** is fake and heavy
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weigh **9** vs **10**
#     - if one is lighter, that one is fake and light
#     - if they balance, then **11** is fake and light
#
# ---
#
# ## Case B: Left side is heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and **heavy**, or
# - one of **5, 6, 7, 8** and **light**
#
# And coins **9–12** are genuine.
#
# Now weigh:
#
# **1, 2, 5** vs **3, 6, 9**
#
# Here 9 is genuine.
#
# ### Subcase B1: Balance
# Then the fake is either:
# - **4 heavy**, or
# - **7 light**, or
# - **8 light**
#
# Weigh **7** vs **8**
# - if one is lighter, that one is fake and light
# - if they balance, then **4** is fake and heavy
#
# ### Subcase B2: Left side is heavier
# Then the fake is either:
# - **1 heavy**
# - **2 heavy**
# - **6 light**
#
# Weigh **1** vs **2**
# - if one is heavier, that one is fake and heavy
# - if they balance, then **6** is fake and light
#
# ### Subcase B3: Right side is heavier
# Then the fake is either:
# - **3 heavy**
# - **5 light**
#
# Weigh **3** vs **9**
# - if 3 is heavier, then **3** is fake and heavy
# - otherwise, **5** is fake and light
#
# ---
#
# ## Case C: Right side is heavier
# This is symmetric to Case B.
#
# Then the fake is either:
#
# - one of **1, 2, 3, 4** and **light**, or
# - one of **5, 6, 7, 8** and **heavy**
#
# Proceed with the same second weighing:
#
# **1, 2, 5** vs **3, 6, 9**
#
# The interpretation is the mirror image of Case B:
#
# - If it balances:
#   - fake is **4 light**, or **7 heavy**, or **8 heavy**
#   - weigh **7** vs **8**
#
# - If left side is heavier:
#   - fake is **3 light**, or **5 heavy**
#   - weigh **3** vs **9**
#
# - If right side is heavier:
#   - fake is **1 light**, **2 light**, or **6 heavy**
#   - weigh **1** vs **2**
#
# ---
#
# ## Summary
# With these three weighings, you can always identify:
#
# 1. **which coin is fake**
# 2. **whether it is heavier or lighter**
#
# ---
#
# If you want, I can also give you:
# - a **compact decision-tree table**, or
# - a **more elegant “balanced ternary” style solution**.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)
# Out:
# The answer is **correct**.
#
# It gives a valid 3-weighing decision tree for the classic 12-coin problem:
#
# - After the first weighing, it correctly splits into:
#   - balanced: fake among 9–12
#   - left heavy: either 1–4 heavy or 5–8 light
#   - right heavy: symmetric case
#
# - In **Case A**, the logic is sound and identifies the fake among 9–12, including whether it is heavy or light.
#
# - In **Case B**, the second weighing
#   **1,2,5 vs 3,6,9**
#   correctly distinguishes among the possibilities:
#   - balance → 4 heavy / 7 light / 8 light
#   - left heavy → 1 heavy / 2 heavy / 6 light
#   - right heavy → 3 heavy / 5 light
#   and the third weighing resolves each subcase.
#
# - **Case C** is the correct mirror image of Case B.
#
# So the proposed strategy does indeed always determine both:
# 1. which coin is counterfeit, and
# 2. whether it is heavier or lighter,
#
# in exactly three weighings.
#
# **Verdict: Correct.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be ripe for an Agentic solution"}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message

messages = [{"role": "user", "content": f"Please propose a pain-point in the {business_area} industry"}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

pain_point = response.choices[0].message.content

messages = [{"role": "user", "content": f"Please propose an Agentic AI solution for the {pain_point} in the {business_area} industry"}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

agentic_solution = response.choices[0].message.content

print(agentic_solution)
# Out:
# Here are **strong industry pain-points** that are good candidates for an **agentic AI** solution, beyond customer support and AP.
#
# ## 1) Sales operations / deal desk for mid-market B2B
# **Pain-point:** Reps slow down waiting on pricing approvals, contract redlines, quote accuracy, and order form checks.
# **Why agentic:** The system must inspect CRM data, pricing rules, discount thresholds, legal clauses, and approval paths, then route or draft the right next step.
# **Wedge product:** **Autonomous quote-to-approval assistant**
# - validates deal terms
# - checks margin/discount policy
# - prepares approval packets
# - escalates risky clauses to legal/finance
#
# ## 2) IT service desk / internal employee support
# **Pain-point:** Employees repeatedly request password resets, access provisioning, software installs, device troubleshooting, and HR/IT policy answers.
# **Why agentic:** It needs to interpret messy requests, identify the employee, verify permissions, operate across identity and endpoint tools, and know when to escalate.
# **Wedge product:** **Autonomous IT helpdesk resolver for access and standard requests**
# - handles access requests
# - resets accounts
# - opens/updates tickets
# - follows policy before taking action
#
# ## 3) Procurement / vendor onboarding
# **Pain-point:** Teams spend too much time collecting vendor info, reviewing compliance docs, chasing W-9s, and completing approval workflows.
# **Why agentic:** It requires gathering missing documents, validating required fields, coordinating across finance/legal/security, and following up with vendors.
# **Wedge product:** **Vendor onboarding coordinator**
# - collects docs
# - checks completeness
# - flags compliance gaps
# - routes for approvals
#
# ## 4) Insurance claims intake and processing
# **Pain-point:** Claims teams handle lots of repetitive intake, evidence collection, policy checks, and exception handling.
# **Why agentic:** The workflow is document-heavy, multi-step, and decision-based, with many handoffs and missing information.
# **Wedge product:** **Claims triage and evidence collector**
# - extracts claim details
# - requests missing documents
# - checks policy coverage
# - routes routine claims for fast-track handling
#
# ## 5) Healthcare revenue cycle / prior authorization support
# **Pain-point:** Staff spend huge effort on eligibility checks, documentation gathering, prior auth follow-ups, and denials management.
# **Why agentic:** It must coordinate across payer portals, EHRs, billing systems, and staff, while adapting to incomplete information.
# **Wedge product:** **Prior auth and denial follow-up agent**
# - gathers required paperwork
# - tracks submission status
# - follows up with payers
# - alerts humans on exceptions
#
# ## 6) Logistics / shipment exception management
# **Pain-point:** Delays, missing paperwork, customs issues, damaged goods, and carrier exceptions create constant operational noise.
# **Why agentic:** The agent has to monitor events, interpret exceptions, contact carriers/customers, and update systems in real time.
# **Wedge product:** **Shipment exception resolution agent**
# - detects delays
# - requests documents
# - notifies stakeholders
# - proposes reroutes or escalations
#
# ## 7) Finance close / reconciliations
# **Pain-point:** Month-end close involves chasing entries, reconciling accounts, resolving mismatches, and getting approvals.
# **Why agentic:** It requires context across ERP, bank feeds, expense systems, and prior close workpapers, plus judgment on exceptions.
# **Wedge product:** **Close assistant for variance and reconciliation exceptions**
# - identifies breaks
# - gathers supporting data
# - drafts explanations
# - routes unresolved items
#
# ---
#
# # Best candidates for an agentic wedge
# If you want the **highest likelihood of near-term success**, I’d rank these as:
#
# ### 1. Customer support triage and resolution
# - clear ROI
# - easy to prove value
# - lots of repetitive cases
# - good starting wedge: billing/access issues
#
# ### 2. AP / invoice exception handling
# - frequent, structured enough to automate partially
# - strong ROI from labor savings and fewer late fees
# - good starting wedge: PO mismatch / missing info cases
#
# ### 3. IT service desk resolution
# - very repetitive
# - easy to control with policies and approvals
# - good integration story with identity and ticketing systems
#
# ### 4. Vendor onboarding
# - less flashy, but sticky and valuable
# - strong workflow + document processing fit
#
# ---
#
# # A simple way to think about “agentic” fit
# The best agentic use cases usually have:
# - **high volume**
# - **repetitive but exception-heavy workflows**
# - **multiple systems**
# - **clear success metrics**
# - **bounded actions with human approval on risky steps**
#
# ---
#
# # If you want a single strongest industry candidate
# If I had to pick **one**:
# ## **Autonomous AP exception handling**
# It’s a very strong wedge because it has:
# - measurable savings
# - clear workflow boundaries
# - frequent exceptions that need judgment
# - low ambiguity compared with many other domains
#
# If you want, I can next give you either:
# 1. a **ranked shortlist by ease of implementation vs. market size**, or
# 2. a **full product spec** for one chosen industry use case.
